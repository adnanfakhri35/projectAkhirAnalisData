# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Kemas Muhammad Adnan Fakhri Sjaf Fawwaz
# - **Email:** adnanfakhri53@gmail.com
# - **ID Dicoding:** adnanfakhri

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 : Bagaimana performa penjualan dalam ecommerce pada tahun 2018 ?
# - Pertanyaan 2 : Apa saja jenis produk yang paling banyak dan sedikit terjual ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load tabel customer

# %%
customers_data = pd.read_csv("https://raw.githubusercontent.com/adnanfakhri35/projectAkhirAnalisData/main/customers_dataset.csv")
customers_data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# #### Load tabel orders_item

# %%
orders_item = pd.read_csv("https://raw.githubusercontent.com/adnanfakhri35/projectAkhirAnalisData/main/order_items_dataset.csv")
orders_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# #### Load tabel orders

# %%
orders = pd.read_csv("https://raw.githubusercontent.com/adnanfakhri35/projectAkhirAnalisData/main/orders_dataset.csv")
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# #### Load tabel products

# %%
products = pd.read_csv("https://raw.githubusercontent.com/adnanfakhri35/projectAkhirAnalisData/main/products_dataset.csv")
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ### Menilai data customers

# %% [markdown]
# #### Memeriksa data dari tiap kolom pada data customers

# %%
customers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# #### Memeriksa apakah ada missing values pada data customers

# %%
customers_data.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# #### Memeriksa apakah ada duplikasi data pada data customers

# %%
print("Jumlah duplikasi: ", customers_data.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Memeriksa parameter statistik dari data customers

# %%
customers_data.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# ### Menilai data orders_item

# %% [markdown]
# #### Memeriksa data pada tiap kolom pada data orders_item

# %%
orders_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Memeriksa apakah ada missing value pada data orders_item

# %%
orders_item.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# #### Memeriksa apakah ada duplikasi data pada data orders_item

# %%
print("Jumlah duplikasi: ", orders_item.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Memeriksa parameter statistik dari data orders_item

# %%
orders_item.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Menilai data orders

# %% [markdown]
# #### Memeriksa data pada tiap kolom orders

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Disini bisa terlihat kalau tipe data dari order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date tidak sesuai, disini memakai tipe data object yang seharusnya memakai tipe data datetime

# %% [markdown]
# #### Memeriksa apakah ada missing value pada data orders

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Disini terlihat bahwa ada 160 missing value pada kolom order_approved_at, 1783 missing value pada kolom order_delivered_carrier_date, 2965 missing value pada kolom order_delivered_customer_date.

# %% [markdown]
# #### Memeriksa apakah ada duplicated value pada data orders

# %%
print("Jumlah duplikasi data :", orders.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# #### Memeriksa parameter statistik dari data orders

# %%
orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# ### Menilai data products

# %% [markdown]
# #### Memeriksa data pada tiap kolom products

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# #### Memeriksa missing value pada data products

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Disini terlihat kolom product_category_name memiliki 610 missing value, kolom product_name_lenght memiliki 610 missing value, kolom product_description_lenght memiliki 610 missing value, kolom product_photos_qty memiliki 610 missing value, kolom product_weight_g memiliki 2 missing value, kolom product_lenght_cm memiliki 2 missing value, kolom product_height_cm memiliki 2 missing value, dan kolom product_width_cm memiliki 2 missing value

# %% [markdown]
# #### Memeriksa duplikasi data pada data products

# %%
print("Jumlah duplikasi data : ", products.duplicated().sum())
# Out:
# Jumlah duplikasi data :  0

# %% [markdown]
# #### Memeriksa parameter statistik dari data products

# %%
products.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Mengganti data type pada data orders

# %% [markdown]
# Data type yang diganti adalah kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date

# %%
orders_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in orders_columns:
  orders[column] = pd.to_datetime(orders[column])

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# ### Menangani missing value pada data orders

# %% [markdown]
# Missing value yang akan ditangani adalah missing value pada kolom orders_approved_at, order_delivered_carrier_date, order_delivered_customer_date

# %% [markdown]
# Pertama kita akan melihat missing values dari kolom order_approved_at, order_delivered_carrier_date, order_delivered_customer_date

# %%
orders[orders.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders[orders.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders[orders.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# Karena data tersebut sangat banyak dan menyimpan informasi yang sangat penting, kita akan mengganti missing values tersebut dengan nilai terbanyak

# %%
orders.order_approved_at.value_counts()
# Out:
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: order_approved_at, Length: 90733, dtype: int64

# %% [markdown]
# Dari kolom order_approved_at kita dapati nilai terbanyaknya adalah 2018-02-27 04:31:10

# %%
orders["order_approved_at"].replace(np.nan ,"2018-02-27 04:31:10", inplace=True)

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Kita sudah berhasil menangani missing value pada kolom order_approved_at

# %%
orders.order_delivered_carrier_date.value_counts()
# Out:
# 2018-05-09 15:48:00    47
# 2018-05-10 18:29:00    32
# 2018-05-07 12:31:00    21
# 2018-05-02 15:15:00    16
# 2018-07-24 16:07:00    16
#                        ..
# 2018-01-03 17:37:21     1
# 2017-10-27 20:07:58     1
# 2017-11-21 18:57:37     1
# 2018-03-21 20:03:37     1
# 2018-03-09 22:11:59     1
# Name: order_delivered_carrier_date, Length: 81018, dtype: int64

# %% [markdown]
# Dari kolom order_delivered_carrier_date kita dapat nilai terbanyaknya adalah 2018-05-09 15:48:00

# %%
orders["order_delivered_carrier_date"].replace(np.nan ,"2018-05-09 15:48:00", inplace=True)

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date        0
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Kita sudah berhasil menangani missing value pada kolom order_delivered_carrier_date

# %%
orders.order_delivered_customer_date.value_counts()
# Out:
# 2018-05-08 23:38:46    3
# 2016-10-27 17:32:07    3
# 2018-02-14 21:09:19    3
# 2017-06-19 18:47:51    3
# 2018-05-08 19:36:48    3
#                       ..
# 2018-07-12 17:48:45    1
# 2018-05-18 18:24:36    1
# 2018-01-17 13:29:13    1
# 2018-06-29 11:21:34    1
# 2018-03-16 13:08:30    1
# Name: order_delivered_customer_date, Length: 95664, dtype: int64

# %% [markdown]
# Dari kolom order_delivered_customer_date kita dapati nilai terbanyaknya adalah 2018-05-08 23:38:46

# %%
orders["order_delivered_customer_date"].replace(np.nan ,"2018-05-08 23:38:46", inplace=True)

# %%
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Kita sudah berhasil menangani semua missing value pada data orders

# %% [markdown]
# ### Menangani missing value pada data products

# %% [markdown]
# Missing value yang akan ditangani adalah missing value pada kolom product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm
#
# Karena missing values pada product_category_name, product_name_lenght, product_description_lenght, product_photos_qty terlalu banyak, kita akan mengganti semuanya dengan modus atau mean dari masing-masing kolom. Kemudian untuk kolom product_weight_g, product_length_cm, product_height_cm, product_width_cm akan kita hapus karena terdapat sedikit missing values

# %% [markdown]
# #### Menangani missing values pada kolom product_category_name

# %%
products.product_category_name.value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %% [markdown]
# Dari data diatas didapatkan nilai cama_mesa_banho merupakan nilai yang paling banyak

# %%
products["product_category_name"].replace(np.nan ,"cama_mesa_banho", inplace=True)

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# kita sudah berhasil menangani missing value pada kolom product_category_name. Selanjutnya kita akan menangani missing value pada kolom product_name_lenght

# %% [markdown]
# #### Menangani missing values pada kolom product_name_lenght

# %% [markdown]
# Kita akan menggunakan mean untuk nilai pengganti pada missing values dalam kolom product_name_lenght

# %%
mean_product_name_length = products["product_name_lenght"].mean()

# %%
products["product_name_lenght"] = products["product_name_lenght"].replace(np.nan, mean_product_name_length)

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght             0
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Kita sudah berhasil menangani missing values pada kolom product_name_lenght

# %% [markdown]
# #### Menangani missing values pada kolom product_description_length

# %% [markdown]
# Kita akan menggunakan mean untuk nilai pengganti pada missing values dalam kolom product_description_lenght

# %%
mean_product_description_length = products["product_description_lenght"].mean()

# %%
products["product_description_lenght"] = products["product_description_lenght"].replace(np.nan, mean_product_description_length)

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght             0
# product_description_lenght      0
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Kita sudah berhasil melakukan penanganan missing values pada kolom product_description_lenght. Selanjutnya kita akan menangani missing values pada kolom product_photos_qty

# %% [markdown]
# #### Menangani missing values pada kolom product_photos_qty

# %% [markdown]
# Kita akan menggunakan mean untuk nilai pengganti pada missing values dalam kolom product_photos_qty

# %%
mean_product_photos_qty = products["product_photos_qty"].mean()

# %%
products["product_photos_qty"] = products["product_photos_qty"].replace(np.nan, mean_product_photos_qty)

# %%
products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              2
# product_length_cm             2
# product_height_cm             2
# product_width_cm              2
# dtype: int64

# %% [markdown]
# Kita sudah berhasil menangani missing values pada product_photos_qty. Terakhir kita akan menghapus missing values pada kolom product_weight_g, product_length_cm, product_height_cm, product_width_cm

# %% [markdown]
# #### Menangani missing values pada kolom product_weight_g, product_length_cm, product_height_cm, product_width_cm
#
# ---

# %% [markdown]
# Karena kolom-kolom tersebut memiliki missing values yang sedikit maka kita akan hapus baris-baris dari data tersebut

# %%
products.dropna(subset="product_weight_g", axis=0, inplace=True)

# %%
products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# Akhirnya kita sudah selesai menangani semua missing values pada data products

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Sesuai dengan pertanyaan yang sudah di tulis di awal, kita akan mencari bagaimana performa penjualan dalam e commerce pada tahun 2018 dan apa saja jenis produk yang paling banyak dan sedikit terjual

# %% [markdown]
# ### Mengeksplorasi data orders & orders_item

# %% [markdown]
# Pertama kita gabungkan dulu data orders dan orders_item agar kita bisa menggunakan group by untuk mendapatkan jawaban dari pertanyaan kita

# %%
orders_item_orders = pd.merge(
    left = orders_item,
    right = orders,
    how="right",
    left_on="order_id",
    right_on="order_id"
)
orders_item_orders = orders_item_orders[(orders_item_orders["order_purchase_timestamp"] > "2018-01-01")]
orders_item_orders.head()
# Out:
#                             order_id  order_item_id  \
# 1   53cdb2fc8bc7dce0b6741e2150273451            1.0
# 2   47770eb9100c2d0c44946d9cf07ec65d            1.0
# 4   ad21c59c0840e6cb83a9ceb5573f8159            1.0
# 13  82566a660a982b15fb86e904c8d32918            1.0
# 14  5ff96c15d0b717ac6ad1f3d77225a350            1.0
#
#                           product_id                         seller_id  \
# 1   595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 2   aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 4   65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
# 13  72a97c271b2e429974398f46b93ae530  094ced053e257ae8cae57205592d6712
# 14  10adb53d8faa890ca7c2f0cbcb68d777  1900267e848ceeba8fa32d80c1a5f5a8
#
#     shipping_limit_date  price  freight_value  \
# 1   2018-07-30 03:24:27  118.7          22.76
# 2   2018-08-13 08:55:23  159.9          19.22
# 4   2018-02-19 20:31:37   19.9           8.72
# ...

# %%
order_bulanan = orders_item_orders.resample(rule="M", on="order_purchase_timestamp").agg({
    "order_id":"count",
})
order_bulanan.index = order_bulanan.index.strftime('%Y-%m-%d')
order_bulanan = order_bulanan.reset_index()
order_bulanan.rename(columns={
    "order_id": "order_count"
}, inplace=True)
order_bulanan.head(50)
# Out:
#   order_purchase_timestamp  order_count
# 0               2018-01-31         8257
# 1               2018-02-28         7706
# 2               2018-03-31         8240
# 3               2018-04-30         7980
# 4               2018-05-31         7945
# 5               2018-06-30         7085
# 6               2018-07-31         7111
# 7               2018-08-31         7308
# 8               2018-09-30           16
# 9               2018-10-31            4

# %% [markdown]
# ### Mengeksplorasi data products dan orders_item

# %% [markdown]
# Kita akan menggabungkan data orders dan product terlebih dahulu kemudian kita gunakan group_by untuk melihat apa barang yang paling banyak dan sedikit terjual

# %%
orders_products = pd.merge(
    left = orders_item_orders,
    right = products,
    how="right",
    left_on="product_id",
    right_on="product_id"
)
orders_products.head()
# Out:
#                            order_id  order_item_id  \
# 0  e17e4f88e31525f7deef66779844ddce            1.0
# 1  5236307716393b7114b53ee991f36956            1.0
# 2  01f66e58769f84129811d43eefd187fb            1.0
# 3  143d00a4f2dde4e0364ee1821577adb3            1.0
# 4  86cafb8794cb99a9b1b77fc8e48fbbbb            1.0
#
#                          product_id                         seller_id  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5  5670f4db5b62c43d542e1b2d56b0cf7c
# 1  3aa071139cb16b67ca9e5dea641aaa2f  b561927807645834b59ef0d16ba55a24
# 2  96bd76ec8810374ed1b65e291975717f  7b07b3c7487f0ea825fc6df75abd658b
# 3  cef67bcfe19066a932b7673e239eb23d  c510bc1718f0f2961eaa42a23330681a
# 4  9dc1a7de274444849c219cff195d0b71  0be8ff43f22e456b4e0371b2245e4d01
#
#    shipping_limit_date   price  freight_value  \
# 0  2018-04-30 17:33:54   10.91           7.39
# 1  2018-02-06 19:11:15  248.00          17.99
# 2  2018-07-11 21:30:20   79.80           7.82
# ...

# %%
product_terbanyak = orders_products.groupby(by="product_category_name").order_id.count().sort_values(ascending=False)
product_terbanyak_df = pd.DataFrame(product_terbanyak)
product_terbanyak_df.head(100)
# Out:
#                                order_id
# product_category_name
# cama_mesa_banho                    6568
# beleza_saude                       5951
# informatica_acessorios             4708
# esporte_lazer                      4527
# moveis_decoracao                   4118
# ...                                 ...
# fashion_esporte                       5
# la_cuisine                            4
# fashion_roupa_infanto_juvenil         3
# cds_dvds_musicais                     1
# seguros_e_servicos                    0
#
# [73 rows x 1 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa penjualan dalam e commerce pada tahun 2018 ?

# %%
plt.figure(figsize=(10,5))
plt.plot(order_bulanan['order_purchase_timestamp'], order_bulanan['order_count'], marker='o', linewidth=3, color="#32CD32")
plt.title("Penjualan dalam e-commerce (2018)", loc="center", fontsize=15)
plt.xticks(fontsize=8, rotation=45)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Apa saja jenis produk yang paling banyak dan sedikit terjual ?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#32cd32", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="order_id", y="product_category_name", data=product_terbanyak_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk paling banyak terjual", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="order_id", y="product_category_name", data=product_terbanyak_df.sort_values(by="order_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk yang paling sedikit terjual", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("5 Produk yang paling banyak dan sedikit terjual", fontsize=20)
plt.show()
# Out:
# <ipython-input-178-ef25d7b2450e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_id", y="product_category_name", data=product_terbanyak_df.head(5), palette=colors, ax=ax[0])
# <ipython-input-178-ef25d7b2450e>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_id", y="product_category_name", data=product_terbanyak_df.sort_values(by="order_id", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 :
# 1. Performa penjualan dalam ecommerce pada tahun 2018 dapat dikatakan cukup stabil dengan selalu diatas 7000 sampai bulan Agustus, namun mulai bulan 09 dan 10 penjualan sangat kecil bahkan dibawah 20
# 2. Penjualan terbanyak adalah pada bulan Januari dan penjualan paling sedikit adalah pada bulan Oktober
#
# - Conclution pertanyaan 2 :
# 1. Jenis produk yang paling banyak terjual adalah cama_mesa_banho, diikuti beleza_saude, esporte_lazer, moveis_decoracao, dan informatica_acessories
# 2. Jenis produk yang paling sedikit terjual adalah seguros_e_services, fashion_roupa_infanto_juvenil, pc_gamer, la_cuisine, dan cds_dvds_musicais
# 3. barang dengan jenis cama_mesa_banho terjual lebih dari 12.000
# 4. barang dengan jenis seguros_e_services hanya terjual 2

# %%
customers_data_df = pd.DataFrame(customers_data)
products_df = pd.DataFrame(products)
orders_item_df = pd.DataFrame(orders_item)
orders_df = pd.DataFrame(orders)

# %%
customers_data_df.to_csv("customers_data.csv", index=False)
products_df.to_csv("products.csv", index=False)
orders_item_df.to_csv("orders_item.csv", index=False)
orders_df.to_csv("orders.csv", index=False)
